# %%
import pandas as pd
import numpy as np
from pathlib import Path

DATA_DIR = Path(".")
IN_CSV   = DATA_DIR / "CTG_clean.csv"    # change if needed
OUT_CSV  = DATA_DIR / "CTG_features.csv" # engineered features

df = pd.read_csv(IN_CSV)
print(df.shape)
print(df.columns.tolist()[:30])
print(df["NSP"].value_counts().sort_index())  # class distribution
# Out:
# (2118, 38)
# ['filename', 'date', 'segfile', 'b', 'e', 'lbe', 'lb', 'ac', 'fm', 'uc', 'astv', 'mstv', 'altv', 'mltv', 'dl', 'ds', 'dp', 'dr', 'width', 'min', 'max', 'nmax', 'nzeros', 'mode', 'mean', 'median', 'variance', 'tendency', 'a', 'c']
# NSP
# 1.0    1648
# 2.0     293
# 3.0     175
# Name: count, dtype: int64

# %%
def pick(df, candidates):
    for c in candidates:
        if c in df.columns:
            return c
    return None

colmap = {
    "baseline": pick(df, ["lb", "baseline", "mean_fhr", "fhr_baseline", "b"]),
    "ac":       pick(df, ["ac", "accelerations"]),
    "dl":       pick(df, ["dl", "decelerations_late", "late_decelerations"]),
    "ds":       pick(df, ["ds", "decelerations_short", "short_decelerations"]),
    "dp":       pick(df, ["dp", "decelerations_prolonged", "prolonged_decelerations"]),
    "uc":       pick(df, ["uc", "uterine_contractions"]),
    "mstv":     pick(df, ["mstv"]),
    "altv":     pick(df, ["altv"]),
    "mltv":     pick(df, ["mltv"]),
    "width":    pick(df, ["width"]),
    "min":      pick(df, ["min"]),
    "max":      pick(df, ["max"]),
}

colmap
# Out:
# {'baseline': 'lb',
#  'ac': 'ac',
#  'dl': 'dl',
#  'ds': 'ds',
#  'dp': 'dp',
#  'uc': 'uc',
#  'mstv': 'mstv',
#  'altv': 'altv',
#  'mltv': 'mltv',
#  'width': 'width',
#  'min': 'min',
#  'max': 'max'}

# %%
df_feat = df.copy()
eps = 1e-6

if colmap["baseline"] is not None:
    base = colmap["baseline"]
    df_feat["feat_tachycardia"] = (df_feat[base] > 160).astype(int)
    df_feat["feat_bradycardia"] = (df_feat[base] < 110).astype(int)

if colmap["altv"] is not None and colmap["mstv"] is not None:
    df_feat["feat_variability_ratio"] = df_feat[colmap["altv"]] / (df_feat[colmap["mstv"]] + eps)

if colmap["ac"] is not None:
    decel_parts = [k for k in ["dl", "ds", "dp"] if colmap[k] is not None]
    if decel_parts:
        df_feat["feat_accel_decel_balance"] = (df_feat[colmap["ac"]] + 1.0) / (
            df_feat[[colmap[k] for k in decel_parts]].sum(axis=1) + 1.0
        )

if colmap["uc"] is not None:
    decel_parts = [k for k in ["dl", "ds", "dp"] if colmap[k] is not None]
    if decel_parts:
        df_feat["feat_decels_per_contraction"] = (
            df_feat[[colmap[k] for k in decel_parts]].sum(axis=1) / (df_feat[colmap["uc"]] + 1.0)
        )

if colmap["max"] is not None and colmap["min"] is not None:
    df_feat["feat_range"] = df_feat[colmap["max"]] - df_feat[colmap["min"]]

if colmap["width"] is not None and colmap["mstv"] is not None:
    df_feat["feat_instability_proxy"] = df_feat[colmap["width"]] / (df_feat[colmap["mstv"]] + 1.0)

num_cols = df_feat.select_dtypes(include=[np.number]).columns
df_feat[num_cols] = df_feat[num_cols].replace([np.inf, -np.inf], np.nan)

for c in ["feat_variability_ratio","feat_accel_decel_balance","feat_decels_per_contraction",
          "feat_range","feat_instability_proxy"]:
    if c in df_feat.columns and df_feat[c].isna().any():
        df_feat[c] = df_feat[c].fillna(df_feat[c].median())

df_feat.shape, [c for c in df_feat.columns if c.startswith("feat_")]
# Out:
# ((2118, 45),
#  ['feat_tachycardia',
#   'feat_bradycardia',
#   'feat_variability_ratio',
#   'feat_accel_decel_balance',
#   'feat_decels_per_contraction',
#   'feat_range',
#   'feat_instability_proxy'])

# %%
df_feat[[c for c in df_feat.columns if c.startswith("feat_")]].describe().T
# Out:
#                               count       mean        std       min  \
# feat_tachycardia             2118.0   0.000000   0.000000  0.000000
# feat_bradycardia             2118.0   0.003305   0.057408  0.000000
# feat_variability_ratio       2118.0  23.923173  60.324052  0.000000
# feat_accel_decel_balance     2118.0   2.542107   3.080302  0.052632
# feat_decels_per_contraction  2118.0   0.378225   0.712147  0.000000
# feat_range                   2118.0  70.486308  38.984821  3.000000
# feat_instability_proxy       2118.0  29.634461  13.686222  2.500000
#
#                                    25%   50%         75%         max
# feat_tachycardia              0.000000   0.0    0.000000    0.000000
# feat_bradycardia              0.000000   0.0    0.000000    1.000000
# feat_variability_ratio        0.000000   0.0   13.333317  454.997725
# feat_accel_decel_balance      0.800000   1.0    3.000000   22.000000
# feat_decels_per_contraction   0.000000   0.0    0.543706   11.000000
# feat_range                   37.000000  68.0  100.000000  180.000000
# feat_instability_proxy       18.947368  28.0   38.367117   78.750000

# %%
df_feat.to_csv(OUT_CSV, index=False)
print("Saved features ->", OUT_CSV.resolve())

df_feat.head(10)
# Out:
# Saved features -> C:\Users\bang kai\Desktop\Datathon\CTG_features.csv
#    filename                date  segfile      b       e    lbe     lb   ac  \
# 0       NaN  849398400000000000      NaN  240.0   357.0  120.0  120.0  0.0
# 1       NaN  831081600000000000      NaN    5.0   632.0  132.0  132.0  4.0
# 2       NaN  831081600000000000      NaN  177.0   779.0  133.0  133.0  2.0
# 3       NaN  831081600000000000      NaN  411.0  1192.0  134.0  134.0  2.0
# 4       NaN  831081600000000000      NaN  533.0  1147.0  132.0  132.0  4.0
# 5       NaN  831081600000000000      NaN    0.0   953.0  134.0  134.0  1.0
# 6       NaN  831081600000000000      NaN  240.0   953.0  134.0  134.0  1.0
# 7       NaN  793411200000000000      NaN   62.0   679.0  122.0  122.0  0.0
# 8       NaN  793411200000000000      NaN  120.0   779.0  122.0  122.0  0.0
# 9       NaN  793411200000000000      NaN  181.0  1192.0  122.0  122.0  0.0
#
#     fm    uc  ...  susp  class  NSP  feat_tachycardia  feat_bradycardia  \
# 0  0.0   0.0  ...   0.0    9.0  2.0                 0                 0
# 1  0.0   4.0  ...   0.0    6.0  1.0                 0                 0
# 2  0.0   5.0  ...   0.0    6.0  1.0                 0                 0
# 3  0.0   6.0  ...   0.0    6.0  1.0                 0                 0
# 4  0.0   5.0  ...   0.0    2.0  1.0                 0                 0
# 5  0.0  10.0  ...   0.0    8.0  3.0                 0                 0
# 6  0.0   9.0  ...   0.0    8.0  3.0                 0                 0
# 7  0.0   0.0  ...   0.0    9.0  3.0                 0                 0
# 8  0.0   1.0  ...   0.0    9.0  3.0                 0                 0
# 9  0.0   3.0  ...   0.0    9.0  3.0                 0                 0
#
#    feat_variability_ratio  feat_accel_decel_balance  \
# 0               85.999828                  1.000000
# 1                0.000000                  1.666667
# 2                0.000000                  1.000000
# 3                0.000000                  1.000000
# 4                0.000000                  5.000000
# 5                0.000000                  0.166667
# 6                0.000000                  0.222222
# 7               11.999976                  1.000000
# 8                9.999980                  1.000000
# 9               19.999933                  1.000000
#
#    feat_decels_per_contraction  feat_range  feat_instability_proxy
# 0                     0.000000        64.0               42.666667
# 1                     0.400000       130.0               41.935484
# 2                     0.333333       130.0               41.935484
# 3                     0.285714       117.0               34.411765
# 4                     0.000000       117.0               34.411765
# 5                     1.000000       150.0               21.739130
# 6                     0.800000       150.0               20.547945
# 7                     0.000000        68.0               45.333333
# 8                     0.000000        68.0               45.333333
# 9                     0.000000        68.0               52.307692
#
# [10 rows x 45 columns]
